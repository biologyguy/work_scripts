# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sn
import pandas as pd

# %%
data = pd.read_csv("data_files/singletons_support.cvs", header=None)
data.columns = ["support", "group"]
data.boxplot("support", "group")
#plt.savefig("data_files/singletons_support.svg")
fig = plt.show()
